# %% [markdown]
# 파이썬 머신러닝 완벽가이드 개정2판
# ch9. 1~4
#  p.584-601

# %% [markdown]
# # 9. 추천 시스템

# %% [markdown]
# ## 01. 추천 시스템의 개요와 배경
# ### [추천 시스템의 개요]
# - 다양한 기업이 추천 시스템을 통해 사용자의 취향을 이해하고 맞춤 상품과 콘텐츠를 제공하는 데 전력을 기울이고 있음

# %% [markdown]
# ### [온라인 스토어의 필수 요소, 추천 시스템]
# - 온라인 스토어는 많은 양의 고객과 상품 관련 데이터를 가짐
# - 이 모든 데이터가사용자가 흥미를 가질 만한 상품을 즉각적으로 추천하는 데 사용됨

# %% [markdown]
# ### [추천 시스템의 유형]
# 추천 시스템
# - **콘텐츠 기반 필터링 방식** (Content based filtering)
# - **협업 필터링 방식** (Collaborative Filtering)
#  * 최근접 이웃 (Nearest Neighbor) 협업 필터링
#  * 잠재 요인 (Latent Factor) 협업 필터링

# %% [markdown]
# ## 02. 콘텐츠 기반 필터링 추천 시스템
# 콘텐츠 기반 필터링 방식 : 사용자가 특정한 아이템을 선호하는 경우, 그 아이템과 비슷한 콘텐츠를 가진 다른 아이템을 추천하는 방식

# %% [markdown]
# ## 03 최근접 이웃 협업 필터링
#
# **협업 필터링** (Collaborative Filtering)
#
# : 사용자가 아이템에 매긴 평점 정보나 상품 구매 이력과 같은 사용자 행동 양식만을 기반으로 추천을 수행하는 것
#
# **협업 필터링의 주요 목적**
# - 사용자-아이템 평점 매트릭스와 같은 축적된 사용자 행동 데이터를 기반으로 사용자가 아직 평가하지 않은 아이템을 예측 평가하는 것
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# **협업 필터링 기반의 추천 시스템**
# - **최근접 이웃 방식**, **잠재 요인 방식**
# - 사용자-아이템 평점 행렬 데이터에만 의지하여 추천을 수행함
#  * 사용자-아이템 평점 행렬
#    - 행 : 개별 사용자
#    - 열 : 개별 아이템
#  * ![image.png](data:image/png;base64,...)
#  * 희소 행렬 특성을 가짐

# %% [markdown]
# **최근접 이웃 방식**
# - 메모리 협업 필터링과 같은 말
# - 사용자 기반 : 당신과 비슷한 고객들이 다음 상품도 구매했습니다
#  * 특정 사용자와 유사한 다른 사용자를 Top-N으로 선정해 이 Top-N 사용자가 좋아하는 아이템을 추천하는 방식
#  * 특정 사용자와 타 사용자 간의 유사도를 측정 -> 가장 유사도가 높은 Top-N 사용자를 추출 -> 그들이 선호하는 아이템을 추천
#    - ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 아이템 기반 : 이 상품을 선택한 다른 고객들은 다음 상품도 구매했습니다
#  * 사용자가 그 아이템을 좋아하는지/싫어하는지 평가 척도가 유사한 아이템을 추천하는 기준이 되는 알고리즘
#    - 사용자 기반 최근접 이웃 데이터 세트와 행과 열이 반대임
#    - ![image.png](data:image/png;base64,...)

# %% [markdown]
# 사용자 기반 vs 아이템 기반 협업 필터링
# - 사용자 기반보다 아이템 기반 협업 필터링의 정확도가 더 높음
# - 최근접 이웃 협업 필터링은 대부분 아이템 기반의 알고리즘을 적용

# %% [markdown]
# ## 04. 잠재 요인 협업 필터링
# ### [잠재 요인 협업 필터링의 이해]
# **잠재 요인 협업 필터링**
#
# : 사용자-아이템 평점 매트릭스 속에 숨어 있는 잠재 요인을 추출해 추천 예측을 할 수 있게 하는 기법
# - 행렬 분해 : 대규모 다차원 행렬을 SVD와 같은 차원 감소 기법으로 분해하는 과정에서 잠재 요인을 추출하는 기법
# - 많은 추천 시스템이 행렬 분해에 기반한 잠재 요인 협업 필터링을 적용함
#
# : 사용자-아이템 평점 행렬 데이터만을 이용해 '잠재 요인'을 끄집어 내는 것
# - '잠재 요인'을 기반으로 다차원 희소 행렬인 사용자-아이템 행렬 데이터를 저차원 밀집 행렬의 사용자-잠재요인 행렬과 아이템-잠재 요인 행렬의 전치 행렬로 분해 가능
# - 두 행렬의 내적을 통해 새로운 예측 사용자-아이템 평점 행렬 데이터를 만듦
# - 사용자가 아직 평점을 부여하지 않는 아이템에 대한 예측 평점을 생성하는 것
#   * ![image.png](data:image/png;base64,...)

# %% [markdown]
# 아직 평가하지 않은 아이템에 대한 예측 평가를 수행
# - ![image.png](data:image/png;base64,...)
#
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### [행렬 분해의 이해]
# **행렬 분해**
#
# : 다차원의 매트릭스를 저차원 매트릭스로 분해하는 기법
# - SVD, NMF 등

# %% [markdown]
# 평점 행렬 R = M x N 차원
#
# - M개의 사용자 행, N개의 아이템 열
# - 행렬 분해를 통해 분해 가능
#  * 사용자-K 차원 잠재 요인 행렬 P (M x N 차원)
#  * K 차원 잠재 요인 - 아이템 행렬 Q, T (M x N 차원)
#    - Q : 아이템-잠재요인 행렬
#    - T : Q의 전치 행렬인 잠재요인-아이템 행렬
#  * ![image.png](data:image/png;base64,...)

# %% [markdown]
# **R 행렬 분해**
#
# R 행렬 : NaN 값을 많이 가지는 고차원의 희소 행렬
# - 저차원의 밀집 행렬인 P, Q 행렬로 분해됨
# - ![image.png](data:image/png;base64,...)

# %% [markdown]
# - R 행렬의 u행렬 사용자, i열 아이템 위치에 있는 평점 데이터
#  * ![image.png](data:image/png;base64,...)
#  - ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 사용자가 평가하지 않은 아이템에 대한 평점도 P, Q 행렬 이용해 예측 가능
#  * ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 사용자-아이템 평점 행렬의 모든 평점 값은 P행렬과 Q.T 행렬의 내적을 통해 예측 평점으로 다시 계산 가능
#  * ![image.png](data:image/png;base64,...)

# %% [markdown]
# **R 행렬을 분해하는 방법**
#
# R 행렬을 P와 Q 행렬로 분해하는 방법
# - 주로 SVD 방식 사용
#  * SVD는 Nan 값이 없는 행렬에만 적용 가능
# - 확률적 경사 하강법, ALS 방식을 이용해 SVD를 수행함

# %% [markdown]
# ### [확률적 경사 하강법을 이용한 행렬 분해]
#
# **P와 Q 행렬로 계산된 예측 R 행렬 값이 실제 R 행렬 값과 가장 최소의 오류를 가질 수 있도록 반복적인 비용 함수 최적화를 통해 P와 Q를 유추해내는 것**
#
# - 확률적 경사 하강법 (SGD) 을 이용한 행렬 분해의 절차
#  * ![image.png](data:image/png;base64,...)
#
# - 실제 값과 예측값의 오류 최소화와 L2 규제를 고려한 비용 함수식
#  * ![image.png](data:image/png;base64,...)

# %% [markdown]
# - 위의 비용 함수를 최소화하기 위해서 새로 업데이트되는 pu, qi 계산식
#  * ![image.png](data:image/png;base64,...)

# %% [markdown]
# **SGD를 이용해 행렬 분해 수행하는 예제**
#
# - 분해하려는 원본 행렬 R을 P와 Q로 분해
# - 다시 P와 Q.T 내적으로 예측 행렬 만들기

# %%
import numpy as np

# 원본 행렬 R 생성, 분해 행렬 P 와 Q 초기화, 잠재 요인 차원 K는 3으로 설정
R = np.array([[4, np.nan, np.nan, 2, np.nan],
              [np.nan, 5, np.nan, 3, 1],
              [np.nan, np.nan, 3,4, 4],
              [5, 2, 1, 2, np.nan]])
num_users, num_items = R.shape
k=3

# P와 Q 행렬의 크기를 지정하고 정규 분포를 가진 임의의 값으로 입력
np.random.seed(1)
P = np.random.normal(scale=1./k, size=(num_users, k))
Q = np.random.normal(scale=1./k, size=(num_items, k))

# %% [markdown]
# 실제 R 행렬과 예측 행렬의 오차를 구하는 get_rmse() 함수 제작

# %%
# 실제 R 행렬과 예측 R 행렬의 오차를 구하는 함수
from sklearn.metrics import mean_squared_error

def get_rmse(R, P, Q, non_zeros):
  error = 0
  # 두 개의 분해된 행렬 P와 Q.T의 내적으로 예측 R 행렬 생성
  full_pred_matrix = np.dot(P, Q.T)

  # 실제 R 행렬에서 널이 아닌 값의 위치 인덱스 추출 -> 실제 R 행렬과 예측 행렬의 RMSE 추출
  x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
  y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
  R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
  full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
  mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
  rmse = np.sqrt(mse)

  return rmse

# %% [markdown]
# SGD 기반으로 행렬 분해를 수행

# %%
# R > 0인 행 위치, 열 위치, 값을 non_zeros 리스트에 저장
non_zeros = [(i, j, R[i, j]) for i in range(num_users) for j in range(num_items) if R[i, j] > 0]

steps = 1000 # SGD 반복 횟수
learning_rate = 0.01 # SGD의 학습률
r_lambda = 0.01 # L2 Regularization 계수

# SGD 기법으로 P와 Q 행렬 업데이트
for step in range(steps):
  for i, j, r in non_zeros:
    # 실제 값과 예측 값의 차이인 오류 값 계산
    eij = r - np.dot(P[i, :], Q[j, :].T)
    # Regularization 반영한 SGD 공식 적용
    P[i, :] = P[i, :] + learning_rate * (eij * Q[j, :] - r_lambda * P[i, :])
    Q[j, :] = Q[j, :] + learning_rate * (eij * P[i, :] - r_lambda * Q[j, :])

  rmse = get_rmse(R, P, Q, non_zeros)
  if (step % 50) == 0:
    print("### iteration step:", step, " rmse:", rmse)
# Out:
# ### iteration step: 0  rmse: 3.2388050277987723
# ### iteration step: 50  rmse: 0.4876723101369648
# ### iteration step: 100  rmse: 0.1564340384819247
# ### iteration step: 150  rmse: 0.07455141311978046
# ### iteration step: 200  rmse: 0.04325226798579314
# ### iteration step: 250  rmse: 0.029248328780878973
# ### iteration step: 300  rmse: 0.022621116143829466
# ### iteration step: 350  rmse: 0.019493636196525135
# ### iteration step: 400  rmse: 0.018022719092132704
# ### iteration step: 450  rmse: 0.01731968595344266
# ### iteration step: 500  rmse: 0.016973657887570753
# ### iteration step: 550  rmse: 0.016796804595895633
# ### iteration step: 600  rmse: 0.01670132290188466
# ### iteration step: 650  rmse: 0.01664473691247669
# ### iteration step: 700  rmse: 0.016605910068210026
# ### iteration step: 750  rmse: 0.016574200475705
# ### iteration step: 800  rmse: 0.01654431582921597
# ### iteration step: 850  rmse: 0.01651375177473524
# ...

# %% [markdown]
# 분해된 P와 Q 함수를 P*Q.T 로 예측 행렬 만들어서 출력하기

# %%
pred_matrix = np.dot(P, Q.T)
print('예측 행렬 : \n', np.round(pred_matrix, 3))
# Out:
# 예측 행렬 :
#  [[3.991 0.897 1.306 2.002 1.663]
#  [6.696 4.978 0.979 2.981 1.003]
#  [6.677 0.391 2.987 3.977 3.986]
#  [4.968 2.005 1.006 2.017 1.14 ]]
